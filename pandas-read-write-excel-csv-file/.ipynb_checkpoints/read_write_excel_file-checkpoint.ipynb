# %% [markdown]
# <h1><b>How to perform read and write operations with an excel(.xlsx) file using Pandas</b></h1>

# %% [markdown]
# To get started with this tutorial, we need to install  a third-party dependency 'xlrd'<br>
# try using pip to install as:-<br>
# 1) for windows:<br>
#         pip install xlrd<br>
#         or if it doesn't work then, you can write like<br>
#         py -m pip install --user xlrd<br>
# 2) for linux:<br>
#         sudo apt-get update<br>
#         sudo apt-get upgrade<br>
#         sudo apt-get install python-xlrd<br>
# 3) for mac:<br>
#         either easy_install xlrd<br>
#         or pip install xlrd<br>
#
# ***for more information visit these links:<br>
#     official python documentation - https://packaging.python.org/tutorials/installing-packages/<br>
#     official PyPi xlrd - https://pypi.org/project/xlrd/<br>
#     official xlrd docs - https://xlrd.readthedocs.io/en/latest/installation.html<br>
#
#     Yet another link may be useful for mac users
#     -- https://gis.stackexchange.com/questions/181858/installing-python-xlw-and-xlrd-libraries-for-qgis-on-mac-osx-with-python-2-6

# %%
import pandas as pd
import xlrd

# %%
myDF = pd.read_excel("budget.xlsx",sheet_name="budget_analysis")
myDF
# Out:
#   My Budget Sheet           Unnamed: 1           Unnamed: 2  \
# 0             NaN                  NaN                  NaN
# 1             NaN                  NaN                  NaN
# 2           Bills  2019-01-01 00:00:00  2019-02-01 00:00:00
# 3          Mobile                  249                  279
# 4             LPG                  600                  644
# 5       Transport                 1000                  850
# 6     Tuition Fee              10416.7              10416.7
# 7   Entertainment                  259                  459
# 8       Groceries                  423                  450
# 9           Total              12947.7              13098.7
#
#             Unnamed: 3           Unnamed: 4           Unnamed: 5  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2  2019-03-01 00:00:00  2019-04-01 00:00:00  2019-05-01 00:00:00
# ...
